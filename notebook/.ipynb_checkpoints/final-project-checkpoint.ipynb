# %%
from keras.utils import image_dataset_from_directory
from keras.preprocessing.image import array_to_img
from keras.applications import ResNet50, ResNet101, EfficientNetB0, VGG16
import os
from PIL import Image
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from keras.models import Model
from sklearn.metrics import classification_report, roc_auc_score, ConfusionMatrixDisplay
import pandas as pd
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import label_binarize
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # interpolation with bicubic spline

# %% [markdown]
# input_dir = "../data/seg_train"
# output_dir = "../data/seg_train_resized"
#
# os.makedirs(output_dir, exist_ok=True)
#
#
# def resize_and_save_images(input_dir, output_dir, target_size):
#     for class_name in os.listdir(input_dir):
#         class_path = os.path.join(input_dir, class_name)
#         if os.path.isdir(class_path):
#             class_output_path = os.path.join(output_dir, class_name)
#             os.makedirs(class_output_path, exist_ok=True)
#
#             for filename in os.listdir(class_path):
#                 input_path = os.path.join(class_path, filename)
#                 output_path = os.path.join(class_output_path, filename)
#
#
#                 try:
#                     with Image.open(input_path) as img:
#                         img = img.resize(target_size, Image.BICUBIC)
#                         img.save(output_path)
#                 except Exception as e:
#                     print(f"Error processing {input_path}: {e}")
#
# resize_and_save_images(input_dir, output_dir, target_size=(224, 224))
#
# print(f"All images have been resized and saved to {output_dir}.")

# %% [markdown]
# # resnet50

# %%
input_shape = (224, 224, 3)
batch_size = 32
epochs = 50

# Data augmentation layer
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomContrast(0.2),
    tf.keras.layers.RandomCrop(200, 200),  # Adjusted cropping dimensions
    tf.keras.layers.Resizing(224, 224),
    tf.keras.layers.RandomTranslation(0.1, 0.1),
])

# Data generators
train_datagen = ImageDataGenerator(
    validation_split=0.2,
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    '../data/seg_train_resized',
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    '../data/seg_train_resized',
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Build model function
def build_model(base_model):
    base_model.trainable = False  # Freeze base model
    inputs = tf.keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = base_model(x, training=False)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    predictions = Dense(train_generator.num_classes, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=predictions)
    return model

# Base models
base_models = {
    "ResNet50": ResNet50(weights='imagenet', include_top=False, pooling='avg'),
    "ResNet101": ResNet101(weights='imagenet', include_top=False, pooling='avg'),
    "EfficientNetB0": EfficientNetB0(weights='imagenet', include_top=False, pooling='avg'),
    "VGG16": VGG16(weights='imagenet', include_top=False, pooling='avg')
}

models = {}
training_history = {}

# Training loop
for name, base_model in base_models.items():
    print(f"Building model for {name}")
    model = build_model(base_model)
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    print(f"Training {name}")
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=epochs,
        callbacks=[early_stopping]
    )

    models[name] = model
    training_history[name] = history

    # Evaluate training and validation metrics
    y_train_true = train_generator.classes
    y_train_pred_proba = model.predict(train_generator)

    y_val_true = validation_generator.classes
    y_val_pred_proba = model.predict(validation_generator)

    # Convert true labels to one-hot encoded for AUC calculation
    y_train_true_bin = label_binarize(y_train_true, classes=range(train_generator.num_classes))
    y_val_true_bin = label_binarize(y_val_true, classes=range(validation_generator.num_classes))

    # Calculate metrics
    train_auc = roc_auc_score(y_train_true_bin, y_train_pred_proba, average='weighted', multi_class='ovr')
    val_auc = roc_auc_score(y_val_true_bin, y_val_pred_proba, average='weighted', multi_class='ovr')

    train_precision = precision_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')
    train_recall = recall_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')
    train_f1 = f1_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')

    val_precision = precision_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')
    val_recall = recall_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')
    val_f1 = f1_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')

    print(f"{name} - Training Precision: {train_precision}, Recall: {train_recall}, F1: {train_f1}, AUC: {train_auc}")
    print(f"{name} - Validation Precision: {val_precision}, Recall: {val_recall}, F1: {val_f1}, AUC: {val_auc}")
    break

# Plot training and validation errors
for name, history in training_history.items():
    plt.figure()
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f"Training and Validation Loss for {name}")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()
# Out:
# Found 11231 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Building model for ResNet50
# Training ResNet50
# Epoch 1/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 468s 1s/step - accuracy: 0.7035 - loss: 4.1590 - val_accuracy: 0.8438 - val_loss: 1.3043
# Epoch 2/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 476s 1s/step - accuracy: 0.7866 - loss: 1.2173 - val_accuracy: 0.8491 - val_loss: 0.7648
# Epoch 3/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 473s 1s/step - accuracy: 0.7954 - loss: 0.8834 - val_accuracy: 0.8691 - val_loss: 0.6615
# Epoch 4/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 477s 1s/step - accuracy: 0.8017 - loss: 0.8282 - val_accuracy: 0.8730 - val_loss: 0.6415
# Epoch 5/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1269s 4s/step - accuracy: 0.7908 - loss: 0.8209 - val_accuracy: 0.8680 - val_loss: 0.6174
# Epoch 6/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 442s 1s/step - accuracy: 0.8023 - loss: 0.7965 - val_accuracy: 0.8634 - val_loss: 0.6157
# Epoch 7/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 477s 1s/step - accuracy: 0.8112 - loss: 0.7640 - val_accuracy: 0.8534 - val_loss: 0.6117
# Epoch 8/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 496s 1s/step - accuracy: 0.8085 - loss: 0.7537 - val_accuracy: 0.8584 - val_loss: 0.5962
# Epoch 9/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 565s 2s/step - accuracy: 0.8089 - loss: 0.7495 - val_accuracy: 0.8741 - val_loss: 0.5489
# Epoch 10/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 529s 2s/step - accuracy: 0.8102 - loss: 0.7218 - val_accuracy: 0.8570 - val_loss: 0.5866
# Epoch 11/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 564s 2s/step - accuracy: 0.8105 - loss: 0.6934 - val_accuracy: 0.8634 - val_loss: 0.5644
# Epoch 12/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 552s 2s/step - accuracy: 0.8204 - loss: 0.6916 - val_accuracy: 0.8627 - val_loss: 0.5420
# Epoch 13/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 539s 2s/step - accuracy: 0.8080 - loss: 0.6831 - val_accuracy: 0.8684 - val_loss: 0.5273
# Epoch 14/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 535s 2s/step - accuracy: 0.8209 - loss: 0.6556 - val_accuracy: 0.8755 - val_loss: 0.4933
# Epoch 15/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 544s 2s/step - accuracy: 0.8125 - loss: 0.6592 - val_accuracy: 0.8705 - val_loss: 0.5204
# Epoch 16/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 535s 2s/step - accuracy: 0.8150 - loss: 0.6598 - val_accuracy: 0.8516 - val_loss: 0.5455
# Epoch 17/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 535s 2s/step - accuracy: 0.8100 - loss: 0.6535 - val_accuracy: 0.8663 - val_loss: 0.4952
# Epoch 18/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 704s 2s/step - accuracy: 0.8198 - loss: 0.6331 - val_accuracy: 0.8951 - val_loss: 0.4516
# Epoch 19/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 792s 2s/step - accuracy: 0.8254 - loss: 0.6215 - val_accuracy: 0.8880 - val_loss: 0.4583
# Epoch 20/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 803s 2s/step - accuracy: 0.8274 - loss: 0.6243 - val_accuracy: 0.8823 - val_loss: 0.4525
# Epoch 21/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 792s 2s/step - accuracy: 0.8267 - loss: 0.6142 - val_accuracy: 0.8606 - val_loss: 0.4924
# Epoch 22/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 748s 2s/step - accuracy: 0.8147 - loss: 0.6197 - val_accuracy: 0.8670 - val_loss: 0.4750
# Epoch 23/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 873s 2s/step - accuracy: 0.8199 - loss: 0.6065 - val_accuracy: 0.8598 - val_loss: 0.4854
# Epoch 24/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 827s 2s/step - accuracy: 0.8272 - loss: 0.6094 - val_accuracy: 0.8784 - val_loss: 0.4412
# Epoch 25/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 648s 2s/step - accuracy: 0.8214 - loss: 0.6055 - val_accuracy: 0.8770 - val_loss: 0.4557
# Epoch 26/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 643s 2s/step - accuracy: 0.8209 - loss: 0.6016 - val_accuracy: 0.8894 - val_loss: 0.4311
# Epoch 27/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 644s 2s/step - accuracy: 0.8244 - loss: 0.5888 - val_accuracy: 0.8324 - val_loss: 0.5184
# Epoch 28/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 644s 2s/step - accuracy: 0.8182 - loss: 0.6178 - val_accuracy: 0.8930 - val_loss: 0.4222
# Epoch 29/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 644s 2s/step - accuracy: 0.8278 - loss: 0.5930 - val_accuracy: 0.8595 - val_loss: 0.4875
# Epoch 30/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 643s 2s/step - accuracy: 0.8266 - loss: 0.5913 - val_accuracy: 0.8755 - val_loss: 0.4619
# Epoch 31/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 644s 2s/step - accuracy: 0.8215 - loss: 0.5998 - val_accuracy: 0.8812 - val_loss: 0.4673
# Epoch 32/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 643s 2s/step - accuracy: 0.8284 - loss: 0.5946 - val_accuracy: 0.8805 - val_loss: 0.4379
# Epoch 33/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 646s 2s/step - accuracy: 0.8268 - loss: 0.5808 - val_accuracy: 0.8812 - val_loss: 0.4431
# Epoch 34/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 643s 2s/step - accuracy: 0.8281 - loss: 0.5897 - val_accuracy: 0.8784 - val_loss: 0.4362
# Epoch 35/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 643s 2s/step - accuracy: 0.8305 - loss: 0.5760 - val_accuracy: 0.8791 - val_loss: 0.4478
# Epoch 36/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 644s 2s/step - accuracy: 0.8294 - loss: 0.5800 - val_accuracy: 0.8855 - val_loss: 0.4378
# Epoch 37/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 644s 2s/step - accuracy: 0.8252 - loss: 0.5882 - val_accuracy: 0.8759 - val_loss: 0.4575
# Epoch 38/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 646s 2s/step - accuracy: 0.8217 - loss: 0.5996 - val_accuracy: 0.8805 - val_loss: 0.4453
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 500s 1s/step
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 124s 1s/step
# ResNet50 - Training Precision: 0.1696852177195567, Recall: 0.1694417238001959, F1: 0.16952419027666243, AUC: 0.5028116000868824
# ResNet50 - Validation Precision: 0.16048517478706195, Recall: 0.16084165477888732, F1: 0.1605926920152683, AUC: 0.5019066080342321

# %%
test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

test_generator = test_datagen.flow_from_directory(
    '../data/seg_test',  # Test data directory
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Important for consistency
)

# Test set evaluation
name = 'ResNet50'
model = models[name];
print(f"Evaluating test set for {name}")
test_loss, test_accuracy = model.evaluate(test_generator)
    # Get true labels and predicted probabilities
y_test_true = test_generator.classes
y_test_pred_proba = model.predict(test_generator)
    
    # Convert true labels to one-hot encoded for AUC calculation
y_test_true_bin = label_binarize(y_test_true, classes=range(test_generator.num_classes))
    
    # Calculate metrics
test_auc = roc_auc_score(y_test_true_bin, y_test_pred_proba, average='weighted', multi_class='ovr')
test_precision = precision_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
test_recall = recall_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
test_f1 = f1_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
    
    # Print metrics
print(f"{name} - Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
print(f"{name} - Test Precision: {test_precision}, Recall: {test_recall}, F1: {test_f1}, AUC: {test_auc}")
# Out:
# Found 3000 images belonging to 6 classes.
# Evaluating test set for ResNet50
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.8785 - loss: 0.4430
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step
# ResNet50 - Test Loss: 0.4961017370223999, Test Accuracy: 0.859666645526886
# ResNet50 - Test Precision: 0.8631805673832521, Recall: 0.8596666666666667, F1: 0.8566371699548402, AUC: 0.9831811354570786

# %% [markdown]
# # tried implementing custom learning rate decay acording to an algorithm in a paper in sources using GPT, but got huge loss and computation time "81/351 ━━━━━━━━━━━━━━━━━━━━ 12:54 3s/step - accuracy: 0.1752 - loss: 31082.6855", not proceeding.
# # also, using built in lr decay is taking a longer computation time " Found 3000 images belonging to 6 classes.
#
# # Epoch 1/50
# # 351/351 ━━━━━━━━━━━━━━━━━━━━ 1202s 3s/step - accuracy: 0.7057 - loss: 4.2111 - val_accuracy: 0.8741 - val_loss: 1.2725 - learning_rate: 0.0010"
# import tensorflow as tf
#
# class ABELScheduler(tf.keras.callbacks.Callback):
#     def __init__(self, initial_lr=1.0, decay_factor=0.3, last_decay_epoch=50):
#         """
#         ABEL Scheduler for adaptive learning rate decay.
#
#         Args:
#         - initial_lr: Initial learning rate.
#         - decay_factor: Factor by which learning rate is reduced.
#         - last_decay_epoch: Explicit decay epoch.
#         """
#         super(ABELScheduler, self).__init__()
#         self.learning_rate = initial_lr
#         self.decay_factor = decay_factor
#         self.last_decay_epoch = last_decay_epoch
#         self.reached_minimum = False
#         self.weight_norms = []  # To track weight norms over epochs
#
#     def on_epoch_end(self, epoch, logs=None):
#         # Compute the weight norm at the end of the epoch
#         weight_norm = sum([tf.norm(w)**2 for w in self.model.trainable_weights])
#         self.weight_norms.append(weight_norm)
#
#         # Only apply the ABEL logic after we have enough weight norms
#         if len(self.weight_norms) >= 3:
#             wt, wt_1, wt_2 = self.weight_norms[-1], self.weight_norms[-2], self.weight_norms[-3]
#             condition = (wt - wt_1) * (wt_1 - wt_2) < 0  # Oscillation condition
#
#             if condition:
#                 if self.reached_minimum:
#                     self.learning_rate *= self.decay_factor
#                     tf.keras.backend.set_value(self.model.optimizer.lr, self.learning_rate)
#                     print(f"Learning rate reduced to {self.learning_rate} at epoch {epoch}")
#                     self.reached_minimum = False
#                 else:
#                     self.reached_minimum = True
#
#         # Decay learning rate explicitly at the specified epoch
#         if epoch == self.last_decay_epoch:
#             self.learning_rate *= self.decay_factor
#             tf.keras.backend.set_value(self.model.optimizer.lr, self.learning_rate)
#             print(f"Learning rate reduced to {self.learning_rate} at epoch {epoch} (scheduled decay)")

# %% [markdown]
# # resnet101

# %%
# Data generators
train_datagen = ImageDataGenerator(
    validation_split=0.2,
    preprocessing_function=tf.keras.applications.resnet.preprocess_input
)
test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet.preprocess_input
)

test_generator = test_datagen.flow_from_directory(
    '../data/seg_test',  # Test data directory
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # Important for consistency
)

train_generator = train_datagen.flow_from_directory(
    '../data/seg_train_resized',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    '../data/seg_train_resized',
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',
    subset='validation'
)



base_models = {
    "ResNet101": ResNet101(weights='imagenet', include_top=False, pooling='avg'),
}


for name, base_model in base_models.items():
    print(f"Building model for {name}")
    model = build_model(base_model)

    model.compile(optimizer=Adam(learning_rate=0.005),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    print(f"Training {name}")

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=epochs,
        callbacks=[early_stopping]
    )

    models[name] = model
    training_history[name] = history

    y_train_true = train_generator.classes
    y_train_pred_proba = model.predict(train_generator)

    y_val_true = validation_generator.classes
    y_val_pred_proba = model.predict(validation_generator)

    y_train_true_bin = label_binarize(y_train_true, classes=range(train_generator.num_classes))
    y_val_true_bin = label_binarize(y_val_true, classes=range(validation_generator.num_classes))

    train_auc = roc_auc_score(y_train_true_bin, y_train_pred_proba, average='weighted', multi_class='ovr')
    val_auc = roc_auc_score(y_val_true_bin, y_val_pred_proba, average='weighted', multi_class='ovr')

    train_precision = precision_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')
    train_recall = recall_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')
    train_f1 = f1_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')

    val_precision = precision_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')
    val_recall = recall_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')
    val_f1 = f1_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')

    print(f"{name} - Training Precision: {train_precision}, Recall: {train_recall}, F1: {train_f1}, AUC: {train_auc}")
    print(f"{name} - Validation Precision: {val_precision}, Recall: {val_recall}, F1: {val_f1}, AUC: {val_auc}")



    test_loss, test_accuracy = model.evaluate(test_generator)
 
    y_test_true = test_generator.classes
    y_test_pred_proba = model.predict(test_generator)
        
    y_test_true_bin = label_binarize(y_test_true, classes=range(test_generator.num_classes))
        
    test_auc = roc_auc_score(y_test_true_bin, y_test_pred_proba, average='weighted', multi_class='ovr')
    test_precision = precision_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
    test_recall = recall_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
    test_f1 = f1_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
        
    print(f"{name} - Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
    print(f"{name} - Test Precision: {test_precision}, Recall: {test_recall}, F1: {test_f1}, AUC: {test_auc}")

    name = "ResNet101"
    history = training_history.get(name)
    plt.figure()
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f"Training and Validation Loss for {name}")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()
# Out:
# Found 3000 images belonging to 6 classes.
# Found 11231 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Building model for ResNet101
# Training ResNet101
# Epoch 1/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 772s 2s/step - accuracy: 0.6847 - loss: 4.2338 - val_accuracy: 0.8477 - val_loss: 1.0550
# Epoch 2/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 712s 2s/step - accuracy: 0.7466 - loss: 1.2790 - val_accuracy: 0.8527 - val_loss: 0.9656
# Epoch 3/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 720s 2s/step - accuracy: 0.7664 - loss: 1.1249 - val_accuracy: 0.8584 - val_loss: 0.7915
# Epoch 4/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 725s 2s/step - accuracy: 0.7692 - loss: 0.9881 - val_accuracy: 0.8442 - val_loss: 0.7102
# Epoch 5/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 707s 2s/step - accuracy: 0.7811 - loss: 0.8813 - val_accuracy: 0.8631 - val_loss: 0.6049
# Epoch 6/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 712s 2s/step - accuracy: 0.7830 - loss: 0.8105 - val_accuracy: 0.8602 - val_loss: 0.5810
# Epoch 7/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 716s 2s/step - accuracy: 0.7794 - loss: 0.7731 - val_accuracy: 0.8516 - val_loss: 0.5891
# Epoch 8/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 719s 2s/step - accuracy: 0.7826 - loss: 0.7683 - val_accuracy: 0.8299 - val_loss: 0.6217
# Epoch 9/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 719s 2s/step - accuracy: 0.7876 - loss: 0.7273 - val_accuracy: 0.8841 - val_loss: 0.5165
# Epoch 10/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 719s 2s/step - accuracy: 0.7892 - loss: 0.7260 - val_accuracy: 0.8684 - val_loss: 0.5157
# Epoch 11/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 711s 2s/step - accuracy: 0.7903 - loss: 0.7220 - val_accuracy: 0.8698 - val_loss: 0.5070
# Epoch 12/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 712s 2s/step - accuracy: 0.7949 - loss: 0.6977 - val_accuracy: 0.8349 - val_loss: 0.5920
# Epoch 13/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 706s 2s/step - accuracy: 0.7915 - loss: 0.6973 - val_accuracy: 0.8584 - val_loss: 0.5266
# Epoch 14/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 696s 2s/step - accuracy: 0.7962 - loss: 0.6918 - val_accuracy: 0.8770 - val_loss: 0.4793
# Epoch 15/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 696s 2s/step - accuracy: 0.7946 - loss: 0.6834 - val_accuracy: 0.8713 - val_loss: 0.4682
# Epoch 16/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 697s 2s/step - accuracy: 0.7984 - loss: 0.6599 - val_accuracy: 0.8513 - val_loss: 0.5146
# Epoch 17/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 709s 2s/step - accuracy: 0.7962 - loss: 0.6620 - val_accuracy: 0.8613 - val_loss: 0.5082
# Epoch 18/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 706s 2s/step - accuracy: 0.7996 - loss: 0.6445 - val_accuracy: 0.8224 - val_loss: 0.5842
# Epoch 19/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 703s 2s/step - accuracy: 0.7987 - loss: 0.6591 - val_accuracy: 0.8663 - val_loss: 0.4800
# Epoch 20/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 700s 2s/step - accuracy: 0.7986 - loss: 0.6518 - val_accuracy: 0.8741 - val_loss: 0.4519
# Epoch 21/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 706s 2s/step - accuracy: 0.7958 - loss: 0.6506 - val_accuracy: 0.8231 - val_loss: 0.5420
# Epoch 22/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 724s 2s/step - accuracy: 0.7926 - loss: 0.6754 - val_accuracy: 0.8702 - val_loss: 0.4606
# Epoch 23/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 785s 2s/step - accuracy: 0.7819 - loss: 0.6675 - val_accuracy: 0.8577 - val_loss: 0.5132
# Epoch 24/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 797s 2s/step - accuracy: 0.7987 - loss: 0.6544 - val_accuracy: 0.8502 - val_loss: 0.4795
# Epoch 25/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1223s 3s/step - accuracy: 0.8023 - loss: 0.6495 - val_accuracy: 0.8670 - val_loss: 0.4561
# Epoch 26/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1198s 3s/step - accuracy: 0.7887 - loss: 0.6513 - val_accuracy: 0.8424 - val_loss: 0.5249
# Epoch 27/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1201s 3s/step - accuracy: 0.7981 - loss: 0.6500 - val_accuracy: 0.8659 - val_loss: 0.4663
# Epoch 28/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1169s 3s/step - accuracy: 0.7993 - loss: 0.6456 - val_accuracy: 0.8730 - val_loss: 0.4680
# Epoch 29/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1173s 3s/step - accuracy: 0.7906 - loss: 0.6550 - val_accuracy: 0.8285 - val_loss: 0.5466
# Epoch 30/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1150s 3s/step - accuracy: 0.7952 - loss: 0.6433 - val_accuracy: 0.8673 - val_loss: 0.4759
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 913s 3s/step
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 228s 5s/step
# ResNet101 - Training Precision: 0.16363002956491077, Recall: 0.16347609295699403, F1: 0.16346642046524582, AUC: 0.49942624154962423
# ResNet101 - Validation Precision: 0.15719159607679645, Recall: 0.15691868758915833, F1: 0.15693078033732452, AUC: 0.4947417710781758
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 240s 3s/step - accuracy: 0.8409 - loss: 0.4946
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 241s 3s/step
# ResNet101 - Test Loss: 0.4763810932636261, Test Accuracy: 0.8579999804496765
# ResNet101 - Test Precision: 0.8579517436755478, Recall: 0.858, F1: 0.8551383795772479, AUC: 0.9813732997833298

# %% [markdown]
# # EfficientNetB0 (removed preprocessing function as documentation states it is included i the function)

# %%
# Data generators
train_datagen = ImageDataGenerator(
    validation_split=0.2
)
test_datagen = ImageDataGenerator()

test_generator = test_datagen.flow_from_directory(
    '../data/seg_test',  
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  
)

train_generator = train_datagen.flow_from_directory(
    '../data/seg_train_resized',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    '../data/seg_train_resized',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)



base_models = {
   "EfficientNetB0": EfficientNetB0(weights='imagenet', include_top=False, pooling='avg'),
}


for name, base_model in base_models.items():
    print(f"Building model for {name}")
    model = build_model(base_model)

    model.compile(optimizer=Adam(learning_rate=0.005),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    print(f"Training {name}")

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=epochs,
        callbacks=[early_stopping]
    )

    models[name] = model
    training_history[name] = history

    y_train_true = train_generator.classes
    y_train_pred_proba = model.predict(train_generator)

    y_val_true = validation_generator.classes
    y_val_pred_proba = model.predict(validation_generator)

    y_train_true_bin = label_binarize(y_train_true, classes=range(train_generator.num_classes))
    y_val_true_bin = label_binarize(y_val_true, classes=range(validation_generator.num_classes))

    train_auc = roc_auc_score(y_train_true_bin, y_train_pred_proba, average='weighted', multi_class='ovr')
    val_auc = roc_auc_score(y_val_true_bin, y_val_pred_proba, average='weighted', multi_class='ovr')

    train_precision = precision_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')
    train_recall = recall_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')
    train_f1 = f1_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')

    val_precision = precision_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')
    val_recall = recall_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')
    val_f1 = f1_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')

    print(f"{name} - Training Precision: {train_precision}, Recall: {train_recall}, F1: {train_f1}, AUC: {train_auc}")
    print(f"{name} - Validation Precision: {val_precision}, Recall: {val_recall}, F1: {val_f1}, AUC: {val_auc}")



    test_loss, test_accuracy = model.evaluate(test_generator)
 
    y_test_true = test_generator.classes
    y_test_pred_proba = model.predict(test_generator)
        
    y_test_true_bin = label_binarize(y_test_true, classes=range(test_generator.num_classes))
        
    test_auc = roc_auc_score(y_test_true_bin, y_test_pred_proba, average='weighted', multi_class='ovr')
    test_precision = precision_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
    test_recall = recall_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
    test_f1 = f1_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
        
    print(f"{name} - Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
    print(f"{name} - Test Precision: {test_precision}, Recall: {test_recall}, F1: {test_f1}, AUC: {test_auc}")

    name = "EfficientNetB0"
    history = training_history.get(name)
    plt.figure()
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f"Training and Validation Loss for {name}")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()
# Out:
# Found 3000 images belonging to 6 classes.
# Found 11231 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Building model for EfficientNetB0
# Training EfficientNetB0
# Epoch 1/50
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 271s 760ms/step - accuracy: 0.7407 - loss: 3.2883 - val_accuracy: 0.8688 - val_loss: 0.8627
# Epoch 2/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 258s 735ms/step - accuracy: 0.8171 - loss: 0.9455 - val_accuracy: 0.8627 - val_loss: 0.7604
# Epoch 3/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 268s 764ms/step - accuracy: 0.8160 - loss: 0.8365 - val_accuracy: 0.8834 - val_loss: 0.6185
# Epoch 4/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 279s 796ms/step - accuracy: 0.8266 - loss: 0.7261 - val_accuracy: 0.8862 - val_loss: 0.5133
# Epoch 5/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 273s 777ms/step - accuracy: 0.8247 - loss: 0.6675 - val_accuracy: 0.8823 - val_loss: 0.5284
# Epoch 6/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 259s 737ms/step - accuracy: 0.8257 - loss: 0.6582 - val_accuracy: 0.8748 - val_loss: 0.5018
# Epoch 7/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 258s 736ms/step - accuracy: 0.8360 - loss: 0.5972 - val_accuracy: 0.8809 - val_loss: 0.4757
# Epoch 8/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 261s 743ms/step - accuracy: 0.8328 - loss: 0.5869 - val_accuracy: 0.8641 - val_loss: 0.5164
# Epoch 9/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 261s 745ms/step - accuracy: 0.8332 - loss: 0.6018 - val_accuracy: 0.8809 - val_loss: 0.4550
# Epoch 10/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 262s 748ms/step - accuracy: 0.8354 - loss: 0.5840 - val_accuracy: 0.8912 - val_loss: 0.4328
# Epoch 11/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 259s 737ms/step - accuracy: 0.8353 - loss: 0.5785 - val_accuracy: 0.8773 - val_loss: 0.4530
# Epoch 12/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 259s 737ms/step - accuracy: 0.8312 - loss: 0.5751 - val_accuracy: 0.8912 - val_loss: 0.4096
# Epoch 13/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 259s 737ms/step - accuracy: 0.8300 - loss: 0.5708 - val_accuracy: 0.8841 - val_loss: 0.4426
# Epoch 14/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 264s 751ms/step - accuracy: 0.8285 - loss: 0.5628 - val_accuracy: 0.8909 - val_loss: 0.3987
# Epoch 15/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 264s 753ms/step - accuracy: 0.8423 - loss: 0.5475 - val_accuracy: 0.8877 - val_loss: 0.4030
# Epoch 16/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 281s 801ms/step - accuracy: 0.8425 - loss: 0.5420 - val_accuracy: 0.8777 - val_loss: 0.4251
# Epoch 17/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 267s 761ms/step - accuracy: 0.8316 - loss: 0.5446 - val_accuracy: 0.8880 - val_loss: 0.4094
# Epoch 18/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 273s 778ms/step - accuracy: 0.8370 - loss: 0.5465 - val_accuracy: 0.8930 - val_loss: 0.3913
# Epoch 19/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 271s 772ms/step - accuracy: 0.8346 - loss: 0.5314 - val_accuracy: 0.8912 - val_loss: 0.4060
# Epoch 20/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 270s 770ms/step - accuracy: 0.8318 - loss: 0.5452 - val_accuracy: 0.8709 - val_loss: 0.4395
# Epoch 21/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 259s 738ms/step - accuracy: 0.8305 - loss: 0.5499 - val_accuracy: 0.8912 - val_loss: 0.4016
# Epoch 22/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 259s 738ms/step - accuracy: 0.8353 - loss: 0.5377 - val_accuracy: 0.8795 - val_loss: 0.4187
# Epoch 23/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 259s 739ms/step - accuracy: 0.8304 - loss: 0.5471 - val_accuracy: 0.8713 - val_loss: 0.4476
# Epoch 24/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 152s 431ms/step - accuracy: 0.8314 - loss: 0.5402 - val_accuracy: 0.8919 - val_loss: 0.3914
# Epoch 25/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 171s 487ms/step - accuracy: 0.8306 - loss: 0.5395 - val_accuracy: 0.8809 - val_loss: 0.3972
# Epoch 26/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 174s 496ms/step - accuracy: 0.8281 - loss: 0.5474 - val_accuracy: 0.8902 - val_loss: 0.3920
# Epoch 27/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 179s 510ms/step - accuracy: 0.8315 - loss: 0.5434 - val_accuracy: 0.8816 - val_loss: 0.4076
# Epoch 28/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 174s 496ms/step - accuracy: 0.8457 - loss: 0.5076 - val_accuracy: 0.8959 - val_loss: 0.3920
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 127s 361ms/step
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 32s 359ms/step
# EfficientNetB0 - Training Precision: 0.17134148034134272, Recall: 0.1710444305938919, F1: 0.17110652354224884, AUC: 0.5023243591392538
# EfficientNetB0 - Validation Precision: 0.1727632206370332, Recall: 0.17296718972895864, F1: 0.17276332606939604, AUC: 0.5091006566856217
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 34s 359ms/step - accuracy: 0.9075 - loss: 0.3613
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step
# EfficientNetB0 - Test Loss: 0.4306110739707947, Test Accuracy: 0.8773333430290222
# EfficientNetB0 - Test Precision: 0.879587225708926, Recall: 0.8773333333333333, F1: 0.8762199047232189, AUC: 0.98605837706054

# %% [markdown]
# # VGG16

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input

train_datagen = ImageDataGenerator(
    validation_split=0.2,
    preprocessing_function=preprocess_input,
)
test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
                                 )

test_generator = test_datagen.flow_from_directory(
    '../data/seg_test',  
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  
)

train_generator = train_datagen.flow_from_directory(
    '../data/seg_train_resized',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    '../data/seg_train_resized',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)



base_models = {
   "VGG16": VGG16(weights='imagenet', include_top=False, pooling='avg')
}


for name, base_model in base_models.items():
    print(f"Building model for {name}")
    model = build_model(base_model)

    model.compile(optimizer=Adam(learning_rate=0.005),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    print(f"Training {name}")

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=epochs,
        callbacks=[early_stopping]
    )

    models[name] = model
    training_history[name] = history

    y_train_true = train_generator.classes
    y_train_pred_proba = model.predict(train_generator)

    y_val_true = validation_generator.classes
    y_val_pred_proba = model.predict(validation_generator)

    y_train_true_bin = label_binarize(y_train_true, classes=range(train_generator.num_classes))
    y_val_true_bin = label_binarize(y_val_true, classes=range(validation_generator.num_classes))

    train_auc = roc_auc_score(y_train_true_bin, y_train_pred_proba, average='weighted', multi_class='ovr')
    val_auc = roc_auc_score(y_val_true_bin, y_val_pred_proba, average='weighted', multi_class='ovr')

    train_precision = precision_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')
    train_recall = recall_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')
    train_f1 = f1_score(y_train_true, np.argmax(y_train_pred_proba, axis=1), average='weighted')

    val_precision = precision_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')
    val_recall = recall_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')
    val_f1 = f1_score(y_val_true, np.argmax(y_val_pred_proba, axis=1), average='weighted')

    print(f"{name} - Training Precision: {train_precision}, Recall: {train_recall}, F1: {train_f1}, AUC: {train_auc}")
    print(f"{name} - Validation Precision: {val_precision}, Recall: {val_recall}, F1: {val_f1}, AUC: {val_auc}")



    test_loss, test_accuracy = model.evaluate(test_generator)
 
    y_test_true = test_generator.classes
    y_test_pred_proba = model.predict(test_generator)
        
    y_test_true_bin = label_binarize(y_test_true, classes=range(test_generator.num_classes))
        
    test_auc = roc_auc_score(y_test_true_bin, y_test_pred_proba, average='weighted', multi_class='ovr')
    test_precision = precision_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
    test_recall = recall_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
    test_f1 = f1_score(y_test_true, np.argmax(y_test_pred_proba, axis=1), average='weighted')
        
    print(f"{name} - Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
    print(f"{name} - Test Precision: {test_precision}, Recall: {test_recall}, F1: {test_f1}, AUC: {test_auc}")

    name = "VGG16"
    history = training_history.get(name)
    plt.figure()
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f"Training and Validation Loss for {name}")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()
# Out:
# Found 3000 images belonging to 6 classes.
# Found 11231 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Building model for VGG16
# Training VGG16
# Epoch 1/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1232s 4s/step - accuracy: 0.6635 - loss: 2.5469 - val_accuracy: 0.7618 - val_loss: 1.0869
# Epoch 2/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1377s 4s/step - accuracy: 0.7144 - loss: 1.0911 - val_accuracy: 0.7971 - val_loss: 0.8402
# Epoch 3/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1501s 4s/step - accuracy: 0.7354 - loss: 0.9546 - val_accuracy: 0.7974 - val_loss: 0.8177
# Epoch 4/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1631s 5s/step - accuracy: 0.7381 - loss: 0.8939 - val_accuracy: 0.8042 - val_loss: 0.7703
# Epoch 5/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1725s 5s/step - accuracy: 0.7412 - loss: 0.8527 - val_accuracy: 0.7885 - val_loss: 0.8173
# Epoch 6/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1577s 4s/step - accuracy: 0.7472 - loss: 0.8284 - val_accuracy: 0.8153 - val_loss: 0.7137
# Epoch 7/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1305s 4s/step - accuracy: 0.7365 - loss: 0.8327 - val_accuracy: 0.7989 - val_loss: 0.7312
# Epoch 8/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1196s 3s/step - accuracy: 0.7392 - loss: 0.8076 - val_accuracy: 0.8192 - val_loss: 0.6411
# Epoch 9/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1206s 3s/step - accuracy: 0.7502 - loss: 0.7913 - val_accuracy: 0.8474 - val_loss: 0.5868
# Epoch 10/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1209s 3s/step - accuracy: 0.7511 - loss: 0.7738 - val_accuracy: 0.8014 - val_loss: 0.7112
# Epoch 11/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1232s 4s/step - accuracy: 0.7488 - loss: 0.7598 - val_accuracy: 0.8377 - val_loss: 0.5900
# Epoch 12/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1252s 4s/step - accuracy: 0.7512 - loss: 0.7675 - val_accuracy: 0.8420 - val_loss: 0.5669
# Epoch 13/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1234s 4s/step - accuracy: 0.7501 - loss: 0.7680 - val_accuracy: 0.8402 - val_loss: 0.5772
# Epoch 14/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1229s 4s/step - accuracy: 0.7449 - loss: 0.7772 - val_accuracy: 0.8213 - val_loss: 0.6453
# Epoch 15/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1225s 3s/step - accuracy: 0.7439 - loss: 0.7545 - val_accuracy: 0.8039 - val_loss: 0.6619
# Epoch 16/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1256s 4s/step - accuracy: 0.7447 - loss: 0.7524 - val_accuracy: 0.8345 - val_loss: 0.5644
# Epoch 17/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1281s 4s/step - accuracy: 0.7538 - loss: 0.7416 - val_accuracy: 0.8267 - val_loss: 0.6219
# Epoch 18/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1254s 4s/step - accuracy: 0.7537 - loss: 0.7361 - val_accuracy: 0.8381 - val_loss: 0.5320
# Epoch 19/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1248s 4s/step - accuracy: 0.7592 - loss: 0.7350 - val_accuracy: 0.7999 - val_loss: 0.7120
# Epoch 20/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1249s 4s/step - accuracy: 0.7539 - loss: 0.7484 - val_accuracy: 0.8110 - val_loss: 0.6663
# Epoch 21/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1265s 4s/step - accuracy: 0.7396 - loss: 0.7678 - val_accuracy: 0.8288 - val_loss: 0.6097
# Epoch 22/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1258s 4s/step - accuracy: 0.7483 - loss: 0.7395 - val_accuracy: 0.8245 - val_loss: 0.6251
# Epoch 23/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1257s 4s/step - accuracy: 0.7586 - loss: 0.7198 - val_accuracy: 0.8431 - val_loss: 0.5499
# Epoch 24/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1241s 4s/step - accuracy: 0.7466 - loss: 0.7667 - val_accuracy: 0.8434 - val_loss: 0.5481
# Epoch 25/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1179s 3s/step - accuracy: 0.7469 - loss: 0.7511 - val_accuracy: 0.8099 - val_loss: 0.6593
# Epoch 26/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1176s 3s/step - accuracy: 0.7545 - loss: 0.7358 - val_accuracy: 0.8324 - val_loss: 0.5785
# Epoch 27/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1184s 3s/step - accuracy: 0.7477 - loss: 0.7284 - val_accuracy: 0.8299 - val_loss: 0.5939
# Epoch 28/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1184s 3s/step - accuracy: 0.7533 - loss: 0.7412 - val_accuracy: 0.7874 - val_loss: 0.7568
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 940s 3s/step
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 234s 3s/step
# VGG16 - Training Precision: 0.17089945050530717, Recall: 0.17086635206125902, F1: 0.16963773103876434, AUC: 0.5019753781882952
# VGG16 - Validation Precision: 0.17096621634426998, Recall: 0.17439372325249644, F1: 0.17084804605850804, AUC: 0.5029960980290513
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 251s 3s/step - accuracy: 0.7461 - loss: 0.7410
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 249s 3s/step
# VGG16 - Test Loss: 0.5821006894111633, Test Accuracy: 0.8140000104904175
# VGG16 - Test Precision: 0.8276903316499726, Recall: 0.814, F1: 0.8106002615939332, AUC: 0.9757277838084412

# %% [markdown]
# # Model Comparison
# - Resnet 50, resnet101, and efficient net b0 have comparable accuracies in the test set
# - efficient net is the best as it performed similiarly to resnets but also took the lowest time to train
# - vgg16 has the lowest accuracy among all the models

# %% [markdown]
# # Sources
# - To use resizing or zero padding? - https://link.springer.com/article/10.1186/s40537-019-0263-7 (either method doesn't impact accuracy but zero padding is slightly faster)
# - choosing interpolation with bicubic - https://www.atlantis-press.com/proceedings/iccsee-13/4822
# - learning rate decay improves accuracy - https://arxiv.org/abs/1908.01878,
# - ABEL early stopping - https://arxiv.org/abs/2103.12682
